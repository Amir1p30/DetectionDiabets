# %%
#introduction
#this code can help you for diagnosis diabets

# %%
#import all the library
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import  LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
df=pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#for preprocessing we need an array
arr_df=np.array(df)

# %%
#division the input ans output 
X=arr_df[:,:8]
Y=arr_df[:,-1]

# %%
#instead of 0 put the mean for precision 
Si=SimpleImputer(missing_values=0,strategy='mean')
X[:,1:5]=Si.fit_transform(X[:,1:5])

# %%
#increase the precision  
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
#devision train and test for algorithms
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
for Mashin in (LogisticRegression(),RandomForestClassifier(),DecisionTreeClassifier(),KNeighborsClassifier(),GaussianNB()):
    Mashin.fit(x_train,y_train)
    result=Mashin.score(x_test,y_test)
    print(Mashin,result)
# Out:
# LogisticRegression() 0.7532467532467533
# RandomForestClassifier() 0.7207792207792207
# DecisionTreeClassifier() 0.7207792207792207
# KNeighborsClassifier() 0.7402597402597403
# GaussianNB() 0.7467532467532467
